# %%
from pymongo import MongoClient

# Crie uma conexão com o MongoDB (ajuste o host e a porta conforme necessário)
client = MongoClient("mongodb+srv://marcomialaret:8bKJBCXab0iliCaf@clustertest1.izap5ni.mongodb.net/")

# %%
# Seleciona o banco de dados
db = client["aula07"]

# Seleciona a coleção
collection = db["cotacoes"]

# %%
import json

# Carrega os dados do arquivo JSON
with open("cotacoes.json", "r") as file:
    data = json.load(file)

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('66269c436a69a6f0b41a1876'), acknowledged=True)

# %%
# Imprime o número de documentos na coleção
print("Documentos na coleção:", collection.count_documents({}))
# Out:
# Documentos na coleção: 1

# %%
for document in collection.find():
    print(document)
# Out:
# {'_id': ObjectId('66269c436a69a6f0b41a1876'), 'USDBRL=X': {'Open': {'2019-04-16': 3.870699882507324, '2019-04-17': 3.903700113296509, '2019-04-18': 3.9374001026153564, '2019-04-19': 3.926300048828125, '2019-04-22': 3.919600009918213, '2019-04-23': 3.9337000846862793, '2019-04-24': 3.9184000492095947, '2019-04-25': 3.9890999794006348, '2019-04-26': 3.953399896621704, '2019-04-29': 3.9237000942230225, '2019-04-30': 3.944499969482422, '2019-05-01': 3.921999931335449, '2019-05-02': 3.926800012588501, '2019-05-03': 3.966599941253662, '2019-05-06': 3.933799982070923, '2019-05-07': 3.9677999019622803, '2019-05-08': 3.9711999893188477, '2019-05-09': 3.926100015640259, '2019-05-10': 3.94569993019104, '2019-05-13': 3.9242000579833984, '2019-05-14': 3.9890999794006348, '2019-05-15': 3.975600004196167, '2019-05-16': 3.9995999336242676, '2019-05-17': 4.046299934387207, '2019-05-20': 4.095799922943115, '2019-05-21': 4.095099925994873, '2019-05-23': 4.036900043487549, '2019-05-24': 4.03840017318725
# ...

# %%
# Exemplo de consulta para encontrar documentos que contêm dados para "USDBRL=X"
query = {"USDBRL=X": {"$exists": True}}
documents = collection.find(query)

for doc in documents:
    print(doc)
# Out:
# {'_id': ObjectId('661f2eec9056a8e3459d812b'), 'USDBRL=X': {'Open': {'2023-04-17': 4.908699989318848, '2023-04-18': 4.939799785614014, '2023-04-19': 4.984300136566162, '2023-04-20': 5.0742998123168945, '2023-04-21': 5.047699928283691, '2023-04-24': 5.047900199890137, '2023-04-25': 5.033400058746338, '2023-04-26': 5.053100109100342, '2023-04-27': 5.043000221252441, '2023-04-28': 4.976200103759766, '2023-05-01': 4.986000061035156, '2023-05-02': 4.9878997802734375, '2023-05-03': 5.038400173187256, '2023-05-04': 4.9944000244140625, '2023-05-05': 4.982600212097168, '2023-05-08': 4.951700210571289, '2023-05-09': 5.007999897003174, '2023-05-10': 4.985899925231934, '2023-05-11': 4.94290018081665, '2023-05-12': 4.929500102996826, '2023-05-15': 4.920199871063232, '2023-05-16': 4.887899875640869, '2023-05-17': 4.9394001960754395, '2023-05-18': 4.937699794769287, '2023-05-19': 4.964399814605713, '2023-05-22': 4.996799945831299, '2023-05-23': 4.966100215911865, '2023-05-24': 4.971199989318848, '20
# ...

# %%
# Exemplo de consulta para valores específicos dentro de um campo aninhado
query = {"USDBRL=X.Open.2023-04-20": {"$gt": 5.0}}
documents = collection.find(query)

for doc in documents:
    print(doc)
# Out:
# {'_id': ObjectId('66269c436a69a6f0b41a1876'), 'USDBRL=X': {'Open': {'2019-04-16': 3.870699882507324, '2019-04-17': 3.903700113296509, '2019-04-18': 3.9374001026153564, '2019-04-19': 3.926300048828125, '2019-04-22': 3.919600009918213, '2019-04-23': 3.9337000846862793, '2019-04-24': 3.9184000492095947, '2019-04-25': 3.9890999794006348, '2019-04-26': 3.953399896621704, '2019-04-29': 3.9237000942230225, '2019-04-30': 3.944499969482422, '2019-05-01': 3.921999931335449, '2019-05-02': 3.926800012588501, '2019-05-03': 3.966599941253662, '2019-05-06': 3.933799982070923, '2019-05-07': 3.9677999019622803, '2019-05-08': 3.9711999893188477, '2019-05-09': 3.926100015640259, '2019-05-10': 3.94569993019104, '2019-05-13': 3.9242000579833984, '2019-05-14': 3.9890999794006348, '2019-05-15': 3.975600004196167, '2019-05-16': 3.9995999336242676, '2019-05-17': 4.046299934387207, '2019-05-20': 4.095799922943115, '2019-05-21': 4.095099925994873, '2019-05-23': 4.036900043487549, '2019-05-24': 4.03840017318725
# ...
